# %%
import pandas as pd
import csv
df=pd.read_csv('game_logs.csv',low_memory=False)
df.head()
# Out:
#        date  number_of_game day_of_week v_name v_league  v_game_number h_name  \
# 0  18710504               0         Thu    CL1       na              1    FW1
# 1  18710505               0         Fri    BS1       na              1    WS3
# 2  18710506               0         Sat    CL1       na              2    RC1
# 3  18710508               0         Mon    CL1       na              3    CH1
# 4  18710509               0         Tue    BS1       na              2    TRO
#
#   h_league  h_game_number  v_score       ...         h_player_7_name  \
# 0       na              1        0       ...              Ed Mincher
# 1       na              1       20       ...            Asa Brainard
# 2       na              1       12       ...              Pony Sager
# 3       na              1       12       ...                Ed Duffy
# 4       na              1        9       ...            Steve Bellan
#
#    h_player_7_def_pos h_player_8_id  h_player_8_name h_player_8_def_pos  \
# 0                 7.0      mcdej101  James McDermott                8.0
# 1                 1.0      burrh101  Henry Burroughs                9.0
# 2                 6.0      birdg101      George Bird                7.0
# 3                 6.0      pinke101       Ed Pinkham                5.0
# 4                 5.0      pikel101         Lip Pike                3.0
#
#   h_player_9_id  h_player_9_name  h_player_9_def_pos  additional_info  \
# 0      kellb105       Bill Kelly                 9.0              NaN
# 1      berth101  Henry Berthrong                 8.0             HTBF
# 2      stirg101       Gat Stires                 9.0              NaN
# 3      zettg101  George Zettlein                 1.0              NaN
# 4      cravb101      Bill Craver                 6.0             HTBF
#
#   acquisition_info
# 0                Y
# 1                Y
# 2                Y
# 3                Y
# 4                Y
#
# [5 rows x 161 columns]

# %%
df1=df.iloc[:,1:19]
df1.head()
# Out:
#    number_of_game day_of_week v_name v_league  v_game_number h_name h_league  \
# 0               0         Thu    CL1       na              1    FW1       na
# 1               0         Fri    BS1       na              1    WS3       na
# 2               0         Sat    CL1       na              2    RC1       na
# 3               0         Mon    CL1       na              3    CH1       na
# 4               0         Tue    BS1       na              2    TRO       na
#
#    h_game_number  v_score  h_score  length_outs day_night completion forefeit  \
# 0              1        0        2         54.0         D        NaN      NaN
# 1              1       20       18         54.0         D        NaN      NaN
# 2              1       12        4         54.0         D        NaN      NaN
# 3              1       12       14         54.0         D        NaN      NaN
# 4              1        9        5         54.0         D        NaN      NaN
#
#   protest park_id  attendance  length_minutes
# 0     NaN   FOR01       200.0           120.0
# 1     NaN   WAS01      5000.0           145.0
# 2     NaN   RCK01      1000.0           140.0
# 3     NaN   CHI01      5000.0           150.0
# 4     NaN   TRO01      3250.0           145.0

# %%
df2=df.loc[:5,:"length_minutes"]
df2.head()
# Out:
#        date  number_of_game day_of_week v_name v_league  v_game_number h_name  \
# 0  18710504               0         Thu    CL1       na              1    FW1
# 1  18710505               0         Fri    BS1       na              1    WS3
# 2  18710506               0         Sat    CL1       na              2    RC1
# 3  18710508               0         Mon    CL1       na              3    CH1
# 4  18710509               0         Tue    BS1       na              2    TRO
#
#   h_league  h_game_number  v_score  h_score  length_outs day_night completion  \
# 0       na              1        0        2         54.0         D        NaN
# 1       na              1       20       18         54.0         D        NaN
# 2       na              1       12        4         54.0         D        NaN
# 3       na              1       12       14         54.0         D        NaN
# 4       na              1        9        5         54.0         D        NaN
#
#   forefeit protest park_id  attendance  length_minutes
# 0      NaN     NaN   FOR01       200.0           120.0
# 1      NaN     NaN   WAS01      5000.0           145.0
# 2      NaN     NaN   RCK01      1000.0           140.0
# 3      NaN     NaN   CHI01      5000.0           150.0
# 4      NaN     NaN   TRO01      3250.0           145.0

# %%
df.index[2]
# Out:
# 2

# %%
df4=df.loc[:9,"length_minutes"]
len(df4)
print(df4.mean())
print(df4.min())
print(df4.max())
# Out:
# 135.0
# 105.0
# 150.0

# %%
df5 = df.loc[(df['day_of_week']=='Sat')^(df['day_of_week']=='Sun')]
df5
# Out:
#             date  number_of_game day_of_week v_name v_league  v_game_number  \
# 2       18710506               0         Sat    CL1       na              2
# 6       18710513               0         Sat    WS3       na              2
# 7       18710513               0         Sat    CH1       na              3
# 14      18710520               0         Sat    PH1       na              1
# 15      18710520               0         Sat    WS3       na              7
# 24      18710527               0         Sat    WS3       na             10
# 30      18710603               0         Sat    TRO       na              8
# 39      18710617               0         Sat    PH1       na              6
# 40      18710617               0         Sat    NY2       na              6
# 47      18710624               0         Sat    RC1       na             13
# 55      18710701               0         Sat    FW1       na             10
# 63      18710708               0         Sat    FW1       na             12
# 73      18710722               0         Sat    PH1       na             17
# 85      18710805               0         Sat    FW1       na             17
# 96      18710826               0         Sat    RC1       na             22
# 101     18710902               0         Sat    NY2       na             26
# 102     18710902               0         Sat    CL1       na             24
# 109     18710909               0         Sat    PH1       na             24
# 113     18710916               0         Sat    NY2       na             30
# 121     18711007               0         Sat    TRO       na             26
# 124     18711021               0         Sat    CH1       na             26
# 128     18720420               0         Sat    BL1       na              2
# 134     18720427               0         Sat    WS4       na              3
# 135     18720427               0         Sat    MID       na              2
# 143     18720504               0         Sat    BS1       na              4
# 144     18720504               0         Sat    BL1       na              8
# 153     18720511               0         Sat    TRO       na              8
# 154     18720511               0         Sat    NY2       na              8
# 162     18720518               0         Sat    CL1       na              4
# 163     18720518               0         Sat    TRO       na             12
# ...          ...             ...         ...    ...      ...            ...
# 171877  20161001               0         Sat    HOU       AL            161
# 171878  20161001               0         Sat    TOR       AL            161
# 171879  20161001               0         Sat    MIN       AL            161
# 171880  20161001               0         Sat    CLE       AL            160
# 171881  20161001               0         Sat    BAL       AL            161
# 171882  20161001               0         Sat    OAK       AL            161
# 171883  20161001               0         Sat    TBA       AL            161
# 171884  20161001               0         Sat    SDN       NL            161
# 171885  20161001               0         Sat    DET       AL            160
# 171886  20161001               0         Sat    CHN       NL            161
# 171887  20161001               0         Sat    MIL       NL            161
# 171888  20161001               0         Sat    NYN       NL            161
# 171889  20161001               0         Sat    LAN       NL            161
# 171890  20161001               0         Sat    PIT       NL            161
# 171891  20161001               0         Sat    MIA       NL            160
# 171892  20161002               0         Sun    HOU       AL            162
# 171893  20161002               0         Sun    TOR       AL            162
# 171894  20161002               0         Sun    MIN       AL            162
# 171895  20161002               0         Sun    CLE       AL            161
# 171896  20161002               0         Sun    BAL       AL            162
# 171897  20161002               0         Sun    OAK       AL            162
# 171898  20161002               0         Sun    TBA       AL            162
# 171899  20161002               0         Sun    SDN       NL            162
# 171900  20161002               0         Sun    DET       AL            161
# 171901  20161002               0         Sun    CHN       NL            162
# 171902  20161002               0         Sun    MIL       NL            162
# 171903  20161002               0         Sun    NYN       NL            162
# 171904  20161002               0         Sun    LAN       NL            162
# 171905  20161002               0         Sun    PIT       NL            162
# 171906  20161002               0         Sun    MIA       NL            161
#
#        h_name h_league  h_game_number  v_score  ...     h_player_7_name  \
# 2         RC1       na              1       12  ...          Pony Sager
# 6         CL1       na              5       12  ...         Ezra Sutton
# 7         FW1       na              2       14  ...          Ed Mincher
# 14        BS1       na              4        8  ...       Harry Schafer
# 15        CL1       na              6       13  ...         Ezra Sutton
# 24        BS1       na              6        6  ...       Harry Schafer
# 30        PH1       na              2        5  ...  Count Sensenderfer
# 39        WS3       na             13       11  ...        Asa Brainard
# 40        BS1       na             11        9  ...       Harry Schafer
# 47        CH1       na             11        8  ...            Ed Duffy
# 55        PH1       na             12        3  ...  Count Sensenderfer
# 63        WS3       na             20        7  ...        Asa Brainard
# 73        CL1       na             16       18  ...         Ezra Sutton
# 85        CH1       na             18       10  ...          Ed Pinkham
# 96        WS3       na             29        7  ...         George Hall
# 101       PH1       na             22        8  ...  Count Sensenderfer
# 102       BS1       na             23       10  ...       Harry Schafer
# 109       BS1       na             25       14  ...       Harry Schafer
# 113       BS1       na             27        7  ...       Harry Schafer
# 121       BS1       na             31        3  ...       Harry Schafer
# 124       TRO       na             28       11  ...   Frank Abercrombie
# 128       WS4       na              1       21  ...         Jacob Doyle
# 134       BL1       na              5        5  ...       Everett Mills
# 135       TRO       na              2       10  ...       Charlie Hodes
# 143       PH1       na              2        7  ...           Cap Anson
# 144       NY2       na              6        9  ...        Chick Fulmer
# 153       BL1       na             10        1  ...       Everett Mills
# 154       BS1       na              8        2  ...       Harry Schafer
# 162       PH1       na              4        7  ...           Cap Anson
# 163       BS1       na              9        2  ...       Harry Schafer
# ...       ...      ...            ...      ...  ...                 ...
# 171877    ANA       AL            161        3  ...       Rafael Ortega
# 171878    BOS       AL            161        4  ...      Jackie Bradley
# 171879    CHA       AL            161        6  ...      Yolmer Sanchez
# 171880    KCA       AL            161        6  ...         Daniel Nava
# 171881    NYA       AL            161        3  ...       Austin Romine
# 171882    SEA       AL            161        9  ...       Leonys Martin
# 171883    TEX       AL            161        4  ...    Jurickson Profar
# 171884    ARI       NL            161        5  ...           Jake Lamb
# 171885    ATL       NL            160        3  ...       Jace Peterson
# 171886    CIN       NL            161        4  ...    Patrick Kivlehan
# 171887    COL       NL            161        4  ...    Cristhian Adames
# 171888    PHI       NL            161        5  ...       Jimmy Paredes
# 171889    SFN       NL            161        0  ...      Gordon Beckham
# 171890    SLN       NL            161        3  ...         Jedd Gyorko
# 171891    WAS       NL            161        1  ...      Pedro Severino
# 171892    ANA       AL            162        1  ...       Rafael Ortega
# 171893    BOS       AL            162        2  ...      Jackie Bradley
# 171894    CHA       AL            162        6  ...          Alex Avila
# 171895    KCA       AL            162        3  ...     Alcides Escobar
# 171896    NYA       AL            162        5  ...         Aaron Hicks
# 171897    SEA       AL            162        3  ...           Ben Gamel
# 171898    TEX       AL            162        6  ...        Elvis Andrus
# 171899    ARI       NL            162        2  ...       Mitch Haniger
# 171900    ATL       NL            161        0  ...       Jace Peterson
# 171901    CIN       NL            162        7  ...     Tucker Barnhart
# 171902    COL       NL            162        6  ...         Pat Valaika
# 171903    PHI       NL            162        2  ...       Andres Blanco
# 171904    SFN       NL            162        1  ...           Joe Panik
# 171905    SLN       NL            162        4  ...         Jedd Gyorko
# 171906    WAS       NL            162        7  ...      Danny Espinosa
#
#         h_player_7_def_pos h_player_8_id   h_player_8_name h_player_8_def_pos  \
# 2                      6.0      birdg101       George Bird                7.0
# 6                      5.0      white104       Elmer White                9.0
# 7                      7.0      donnp101     Pete Donnelly                8.0
# 14                     5.0      conef101         Fred Cone                7.0
# 15                     5.0      johnc105   William Johnson                9.0
# 24                     5.0      conef101         Fred Cone                7.0
# 30                     8.0      meyel102      Levi Meyerle                5.0
# 39                     1.0      hallg101       George Hall                8.0
# 40                     5.0      conef101         Fred Cone                7.0
# 47                     6.0      pinke101        Ed Pinkham                5.0
# 55                     8.0      meyel102      Levi Meyerle                5.0
# 63                     1.0      hallg101       George Hall                8.0
# 73                     5.0      johnc105   William Johnson                4.0
# 85                     9.0      hodec101     Charlie Hodes                5.0
# 96                     8.0      burrh101   Henry Burroughs                9.0
# 101                    8.0      meyel102      Levi Meyerle                5.0
# 102                    5.0      barrf102     Frank Barrows                7.0
# 109                    5.0      barrf102     Frank Barrows                7.0
# 113                    5.0      barrf102     Frank Barrows                7.0
# 121                    5.0      barrf102     Frank Barrows                7.0
# 124                    6.0      bells101      Steve Bellan                5.0
# 128                    6.0      steab101      Bill Stearns                1.0
# 134                    3.0      hallg101       George Hall                8.0
# 135                    2.0      zettg101   George Zettlein                1.0
# 143                    5.0      mcgem101      Mike McGeary                6.0
# 144                    5.0      hickn101         Nat Hicks                2.0
# 153                    3.0      hallg101       George Hall                8.0
# 154                    5.0      rogef101     Fraley Rogers                3.0
# 162                    5.0      mcgem101      Mike McGeary                6.0
# 163                    5.0      rogef101     Fraley Rogers                9.0
# ...                    ...           ...               ...                ...
# 171877                 8.0      gratj001     Juan Graterol                2.0
# 171878                 8.0      hilla001        Aaron Hill                5.0
# 171879                 4.0      narvo001      Omar Narvaez                2.0
# 171880                 3.0      cuthc001  Cheslor Cuthbert                5.0
# 171881                 2.0      austt001      Tyler Austin                9.0
# 171882                 8.0      zunim001       Mike Zunino                2.0
# 171883                 6.0      gallj002        Joey Gallo                5.0
# 171884                 5.0      herno002   Oscar Hernandez                2.0
# 171885                 4.0      swand001    Dansby Swanson                6.0
# 171886                 9.0      cabrr001     Ramon Cabrera                2.0
# 171887                 6.0      woltt001      Tony Wolters                2.0
# 171888                 7.0      altha001     Aaron Altherr                9.0
# 171889                 5.0      panij002         Joe Panik                4.0
# 171890                 4.0      gricr001    Randal Grichuk                8.0
# 171891                 2.0      espid001    Danny Espinosa                6.0
# 171892                 8.0      perec003      Carlos Perez                2.0
# 171893                 8.0      leons001        Sandy Leon                2.0
# 171894                 2.0      sancc001    Yolmer Sanchez                4.0
# 171895                 6.0      cuthc001  Cheslor Cuthbert                5.0
# 171896                 9.0      torrr001   Ronald Torreyes                5.0
# 171897                 7.0      iannc001    Chris Iannetta                2.0
# 171898                 6.0      rua-r001          Ryan Rua                3.0
# 171899                 8.0      goset001   Tuffy Gosewisch                2.0
# 171900                 4.0      swand001    Dansby Swanson                6.0
# 171901                 2.0      rendt001        Tony Renda                9.0
# 171902                 4.0      adamc001  Cristhian Adames                6.0
# 171903                 6.0      altha001     Aaron Altherr                9.0
# 171904                 4.0      gillc001   Conor Gillaspie                5.0
# 171905                 4.0      gricr001    Randal Grichuk                8.0
# 171906                 6.0      lobaj001      Jose Lobaton                2.0
#
#        h_player_9_id    h_player_9_name  h_player_9_def_pos  additional_info  \
# 2           stirg101         Gat Stires                 9.0              NaN
# 6           bassj101          John Bass                 6.0              NaN
# 7           kellb105         Bill Kelly                 9.0              NaN
# 14          spala101        Al Spalding                 1.0             HTBF
# 15          bassj101          John Bass                 6.0             HTBF
# 24          spala101        Al Spalding                 1.0              NaN
# 30          heubg101      George Heubel                 9.0             HTBF
# 39          berth101    Henry Berthrong                 7.0             HTBF
# 40          spala101        Al Spalding                 1.0             HTBF
# 47          zettg101    George Zettlein                 1.0              NaN
# 55          bechg101     George Bechtel                 9.0             HTBF
# 63          burrh101    Henry Burroughs                 7.0              NaN
# 73          bassj101          John Bass                 6.0             HTBF
# 85          zettg101    George Zettlein                 1.0             HTBF
# 96          bealt101        Tommy Beals                 4.0              NaN
# 101         berrt101          Tom Berry                 9.0              NaN
# 102         wrigh101       Harry Wright                 8.0             HTBF
# 109         wrigh101       Harry Wright                 8.0             HTBF
# 113         wrigh101       Harry Wright                 8.0             HTBF
# 121         wrigh101       Harry Wright                 8.0              NaN
# 124         connn101         Ned Connor                 9.0              NaN
# 128         yeatb101       Bill Yeatman                 9.0              NaN
# 134         caret101          Tom Carey                 5.0              NaN
# 135         woodj106         Jimmy Wood                 4.0              NaN
# 143         mackd101         Denny Mack                 3.0              NaN
# 144         mcmuj101      John McMullin                 9.0              NaN
# 153         mathb101      Bobby Mathews                 1.0              NaN
# 154         wrigh101       Harry Wright                 8.0              NaN
# 162         mackd101         Denny Mack                 3.0              NaN
# 163         wrigh101       Harry Wright                 8.0              NaN
# ...              ...                ...                 ...              ...
# 171877      cowak001       Kaleb Cowart                 4.0              NaN
# 171878      vazqc001  Christian Vazquez                 2.0              NaN
# 171879      garcl004       Leury Garcia                 8.0              NaN
# 171880      buted001        Drew Butera                 2.0              NaN
# 171881      torrr001    Ronald Torreyes                 6.0              NaN
# 171882      martk001        Ketel Marte                 6.0              NaN
# 171883      chirr001  Robinson Chirinos                 2.0              NaN
# 171884      brada001     Archie Bradley                 1.0              NaN
# 171885      blaia001        Aaron Blair                 1.0              NaN
# 171886      adlet001        Tim Adleman                 1.0              NaN
# 171887      hoffj003       Jeff Hoffman                 1.0              NaN
# 171888      kleip001         Phil Klein                 1.0              NaN
# 171889      blact002           Ty Blach                 1.0              NaN
# 171890      wachm001      Michael Wacha                 1.0              NaN
# 171891      roart001       Tanner Roark                 1.0              NaN
# 171892      pennc001   Cliff Pennington                 4.0              NaN
# 171893      benia002  Andrew Benintendi                 7.0              NaN
# 171894      garcl004       Leury Garcia                 8.0              NaN
# 171895      buted001        Drew Butera                 2.0              NaN
# 171896      solad001     Donovan Solano                 4.0              NaN
# 171897      freem002       Mike Freeman                 4.0              NaN
# 171898      profj001   Jurickson Profar                 4.0              NaN
# 171899      kochm001          Matt Koch                 1.0              NaN
# 171900      tehej001      Julio Teheran                 1.0              NaN
# 171901      stepr002  Robert Stephenson                 1.0              NaN
# 171902      marqg001     German Marquez                 1.0              NaN
# 171903      eickj001     Jerad Eickhoff                 1.0              NaN
# 171904      moorm003         Matt Moore                 1.0              NaN
# 171905      waina001    Adam Wainwright                 1.0              NaN
# 171906      schem001       Max Scherzer                 1.0              NaN
#
#        acquisition_info
# 2                     Y
# 6                     Y
# 7                     Y
# 14                    Y
# 15                    Y
# 24                    Y
# 30                    Y
# 39                    Y
# 40                    Y
# 47                    Y
# 55                    Y
# 63                    Y
# 73                    Y
# 85                    Y
# 96                    Y
# 101                   Y
# 102                   Y
# 109                   Y
# 113                   Y
# 121                   Y
# 124                   Y
# 128                   Y
# 134                   Y
# 135                   Y
# 143                   Y
# 144                   Y
# 153                   Y
# 154                   Y
# 162                   Y
# 163                   Y
# ...                 ...
# 171877                Y
# 171878                Y
# 171879                Y
# 171880                Y
# 171881                Y
# 171882                Y
# 171883                Y
# 171884                Y
# 171885                Y
# 171886                Y
# 171887                Y
# 171888                Y
# 171889                Y
# 171890                Y
# 171891                Y
# 171892                Y
# 171893                Y
# 171894                Y
# 171895                Y
# 171896                Y
# 171897                Y
# 171898                Y
# 171899                Y
# 171900                Y
# 171901                Y
# 171902                Y
# 171903                Y
# 171904                Y
# 171905                Y
# 171906                Y
#
# [55463 rows x 161 columns]

# %%
df6=df5.iloc[:100000,1:19]
df7= df6[df6['day_night']=="D"]
df7= df7.loc[:,"attendance"]
df7.mean()
# Out:
# 20814.673415683726

# %%
df8= df6[df6['day_night']=="N"]
df8= df8.loc[:,"attendance"]
df8.mean()
# Out:
# 30337.312185929648

# %% [markdown]
# Time out

# %%
df7= df.iloc[:,1:5]
grp = df7.groupby("day_of_week")
# The keys[0]=key and item = keys[1] are the data frames that were grouped based on a key = 'color'
for keys in grp:
    print(keys[1],"\n")
# Out:
#         number_of_game day_of_week v_name v_league
# 1                    0         Fri    BS1       na
# 13                   0         Fri    WS3       na
# 22                   0         Fri    RC1       na
# 23                   0         Fri    FW1       na
# 28                   0         Fri    CH1       na
# 29                   0         Fri    TRO       na
# 54                   0         Fri    WS3       na
# 61                   0         Fri    FW1       na
# 62                   0         Fri    BS1       na
# 69                   0         Fri    PH1       na
# 77                   0         Fri    NY2       na
# 78                   0         Fri    TRO       na
# 84                   0         Fri    PH1       na
# 90                   0         Fri    CL1       na
# 94                   0         Fri    RC1       na
# 95                   0         Fri    TRO       na
# 112                  0         Fri    RC1       na
# 115                  0         Fri    WS3       na
# 118                  0         Fri    BS1       na
# 119                  0         Fri    WS3       na
# 133                  0         Fri    MID       na
# 142                  0         Fri    BR2       na
# 161                  0         Fri    WS3       na
# 171                  0         Fri    MID       na
# 172                  0         Fri    WS4       na
# 173                  0         Fri    CL1       na
# 200                  0         Fri    BR1       na
# 205                  0         Fri    PH1       na
# 215                  0         Fri    CL1       na
# 230                  0         Fri    MID       na
# ...                ...         ...    ...      ...
# 171767               0         Fri    ARI       NL
# 171768               0         Fri    CHA       AL
# 171769               0         Fri    KCA       AL
# 171770               0         Fri    ANA       AL
# 171771               0         Fri    SEA       AL
# 171772               0         Fri    TEX       AL
# 171773               0         Fri    BOS       AL
# 171774               0         Fri    NYA       AL
# 171775               0         Fri    SLN       NL
# 171776               0         Fri    COL       NL
# 171777               0         Fri    ATL       NL
# 171778               0         Fri    CIN       NL
# 171779               0         Fri    PHI       NL
# 171780               0         Fri    WAS       NL
# 171781               0         Fri    SFN       NL
# 171862               0         Fri    HOU       AL
# 171863               0         Fri    TOR       AL
# 171864               0         Fri    MIN       AL
# 171865               0         Fri    CLE       AL
# 171866               0         Fri    BAL       AL
# 171867               0         Fri    OAK       AL
# 171868               0         Fri    TBA       AL
# 171869               0         Fri    SDN       NL
# 171870               0         Fri    DET       AL
# 171871               0         Fri    CHN       NL
# 171872               0         Fri    MIL       NL
# 171873               0         Fri    NYN       NL
# 171874               0         Fri    LAN       NL
# 171875               0         Fri    PIT       NL
# 171876               0         Fri    MIA       NL
#
# [25152 rows x 4 columns]
#
#         number_of_game day_of_week v_name v_league
# 3                    0         Mon    CL1       na
# 8                    0         Mon    WS3       na
# 16                   0         Mon    RC1       na
# 17                   0         Mon    WS3       na
# 25                   0         Mon    RC1       na
# 31                   0         Mon    CH1       na
# 32                   0         Mon    RC1       na
# 34                   0         Mon    CL1       na
# 41                   0         Mon    FW1       na
# 42                   0         Mon    CL1       na
# 48                   0         Mon    FW1       na
# 49                   0         Mon    CL1       na
# 50                   0         Mon    BS1       na
# 56                   0         Mon    NY2       na
# 64                   0         Mon    BS1       na
# 65                   0         Mon    NY2       na
# 70                   0         Mon    WS3       na
# 71                   0         Mon    PH1       na
# 74                   0         Mon    PH1       na
# 79                   0         Mon    NY2       na
# 86                   0         Mon    BS1       na
# 92                   0         Mon    RC1       na
# 97                   0         Mon    CH1       na
# 103                  0         Mon    PH1       na
# 104                  0         Mon    CL1       na
# 114                  0         Mon    PH1       na
# 122                  0         Mon    TRO       na
# 125                  0         Mon    CH1       na
# 126                  0         Mon    PH1       na
# 129                  0         Mon    NY2       na
# ...                ...         ...    ...      ...
# 171621               0         Mon    LAN       NL
# 171622               0         Mon    TBA       AL
# 171623               0         Mon    COL       NL
# 171624               0         Mon    MIA       NL
# 171625               0         Mon    MIL       NL
# 171626               0         Mon    PIT       NL
# 171627               0         Mon    SDN       NL
# 171628               0         Mon    CHN       NL
# 171629               0         Mon    NYN       NL
# 171716               0         Mon    BOS       AL
# 171717               0         Mon    CHA       AL
# 171718               0         Mon    HOU       AL
# 171719               0         Mon    TOR       AL
# 171720               0         Mon    ANA       AL
# 171721               0         Mon    CIN       NL
# 171722               0         Mon    SLN       NL
# 171723               0         Mon    SFN       NL
# 171724               0         Mon    WAS       NL
# 171725               0         Mon    ATL       NL
# 171726               0         Mon    ARI       NL
# 171811               0         Mon    OAK       AL
# 171812               0         Mon    TBA       AL
# 171813               0         Mon    CLE       AL
# 171814               0         Mon    SEA       AL
# 171815               0         Mon    MIL       NL
# 171816               0         Mon    NYA       AL
# 171817               0         Mon    NYN       NL
# 171818               0         Mon    CHN       NL
# 171819               0         Mon    CIN       NL
# 171820               0         Mon    ARI       NL
#
# [19194 rows x 4 columns]
#
#         number_of_game day_of_week v_name v_league
# 2                    0         Sat    CL1       na
# 6                    0         Sat    WS3       na
# 7                    0         Sat    CH1       na
# 14                   0         Sat    PH1       na
# 15                   0         Sat    WS3       na
# 24                   0         Sat    WS3       na
# 30                   0         Sat    TRO       na
# 39                   0         Sat    PH1       na
# 40                   0         Sat    NY2       na
# 47                   0         Sat    RC1       na
# 55                   0         Sat    FW1       na
# 63                   0         Sat    FW1       na
# 73                   0         Sat    PH1       na
# 85                   0         Sat    FW1       na
# 96                   0         Sat    RC1       na
# 101                  0         Sat    NY2       na
# 102                  0         Sat    CL1       na
# 109                  0         Sat    PH1       na
# 113                  0         Sat    NY2       na
# 121                  0         Sat    TRO       na
# 124                  0         Sat    CH1       na
# 128                  0         Sat    BL1       na
# 134                  0         Sat    WS4       na
# 135                  0         Sat    MID       na
# 143                  0         Sat    BS1       na
# 144                  0         Sat    BL1       na
# 153                  0         Sat    TRO       na
# 154                  0         Sat    NY2       na
# 162                  0         Sat    CL1       na
# 163                  0         Sat    TRO       na
# ...                ...         ...    ...      ...
# 171782               0         Sat    ARI       NL
# 171783               0         Sat    CHA       AL
# 171784               0         Sat    KCA       AL
# 171785               0         Sat    ANA       AL
# 171786               0         Sat    SEA       AL
# 171787               0         Sat    TEX       AL
# 171788               0         Sat    BOS       AL
# 171789               0         Sat    NYA       AL
# 171790               0         Sat    SLN       NL
# 171791               0         Sat    COL       NL
# 171792               0         Sat    ATL       NL
# 171793               0         Sat    CIN       NL
# 171794               0         Sat    PHI       NL
# 171795               0         Sat    WAS       NL
# 171796               0         Sat    SFN       NL
# 171877               0         Sat    HOU       AL
# 171878               0         Sat    TOR       AL
# 171879               0         Sat    MIN       AL
# 171880               0         Sat    CLE       AL
# 171881               0         Sat    BAL       AL
# 171882               0         Sat    OAK       AL
# 171883               0         Sat    TBA       AL
# 171884               0         Sat    SDN       NL
# 171885               0         Sat    DET       AL
# 171886               0         Sat    CHN       NL
# 171887               0         Sat    MIL       NL
# 171888               0         Sat    NYN       NL
# 171889               0         Sat    LAN       NL
# 171890               0         Sat    PIT       NL
# 171891               0         Sat    MIA       NL
#
# [28891 rows x 4 columns]
#
#         number_of_game day_of_week v_name v_league
# 900                  0         Sun    WS6       na
# 912                  0         Sun    WS6       na
# 2737                 0         Sun    SL4       AA
# 2835                 0         Sun    PH4       AA
# 2836                 0         Sun    PT1       AA
# 2865                 0         Sun    BL2       AA
# 2891                 0         Sun    BL2       AA
# 2892                 0         Sun    PH4       AA
# 2919                 0         Sun    LS2       AA
# 2947                 0         Sun    CN2       AA
# 2974                 0         Sun    SL4       AA
# 3076                 0         Sun    CN2       AA
# 3101                 0         Sun    PH4       AA
# 3124                 0         Sun    PT1       AA
# 3125                 0         Sun    PH4       AA
# 3152                 0         Sun    CN2       AA
# 3153                 0         Sun    PT1       AA
# 3175                 0         Sun    BL2       AA
# 3198                 0         Sun    CN2       AA
# 3252                 0         Sun    CN2       AA
# 3277                 0         Sun    LS2       AA
# 3310                 0         Sun    SL4       AA
# 3345                 0         Sun    CN2       AA
# 3346                 0         Sun    SL4       AA
# 3381                 0         Sun    CL5       AA
# 3411                 0         Sun    LS2       AA
# 3521                 0         Sun    BL2       AA
# 3522                 0         Sun    NY4       AA
# 3560                 0         Sun    NY4       AA
# 3561                 0         Sun    BL2       AA
# ...                ...         ...    ...      ...
# 171715               0         Sun    SLN       NL
# 171797               0         Sun    ARI       NL
# 171798               0         Sun    CHA       AL
# 171799               0         Sun    KCA       AL
# 171800               0         Sun    ANA       AL
# 171801               0         Sun    SEA       AL
# 171802               0         Sun    TEX       AL
# 171803               0         Sun    BOS       AL
# 171804               0         Sun    NYA       AL
# 171805               0         Sun    SLN       NL
# 171806               0         Sun    COL       NL
# 171807               0         Sun    CIN       NL
# 171808               0         Sun    PHI       NL
# 171809               0         Sun    WAS       NL
# 171810               0         Sun    SFN       NL
# 171892               0         Sun    HOU       AL
# 171893               0         Sun    TOR       AL
# 171894               0         Sun    MIN       AL
# 171895               0         Sun    CLE       AL
# 171896               0         Sun    BAL       AL
# 171897               0         Sun    OAK       AL
# 171898               0         Sun    TBA       AL
# 171899               0         Sun    SDN       NL
# 171900               0         Sun    DET       AL
# 171901               0         Sun    CHN       NL
# 171902               0         Sun    MIL       NL
# 171903               0         Sun    NYN       NL
# 171904               0         Sun    LAN       NL
# 171905               0         Sun    PIT       NL
# 171906               0         Sun    MIA       NL
#
# [26572 rows x 4 columns]
#
#         number_of_game day_of_week v_name v_league
# 0                    0         Thu    CL1       na
# 5                    0         Thu    CH1       na
# 12                   0         Thu    NY2       na
# 21                   0         Thu    TRO       na
# 27                   0         Thu    RC1       na
# 33                   0         Thu    CH1       na
# 38                   0         Thu    RC1       na
# 46                   0         Thu    WS3       na
# 53                   0         Thu    PH1       na
# 60                   0         Thu    CL1       na
# 67                   0         Thu    TRO       na
# 68                   0         Thu    BS1       na
# 72                   0         Thu    PH1       na
# 76                   0         Thu    WS3       na
# 81                   0         Thu    NY2       na
# 82                   0         Thu    FW1       na
# 83                   0         Thu    BS1       na
# 89                   0         Thu    CL1       na
# 127                  0         Thu    BL1       na
# 132                  0         Thu    NY2       na
# 140                  0         Thu    BS1       na
# 141                  0         Thu    BR2       na
# 151                  0         Thu    BS1       na
# 152                  0         Thu    TRO       na
# 159                  0         Thu    CL1       na
# 160                  0         Thu    TRO       na
# 177                  0         Thu    BL1       na
# 183                  0         Thu    BL1       na
# 184                  0         Thu    NY2       na
# 190                  0         Thu    BR2       na
# ...                ...         ...    ...      ...
# 171662               0         Thu    NYA       AL
# 171663               0         Thu    CLE       AL
# 171664               0         Thu    MIN       AL
# 171665               0         Thu    OAK       AL
# 171666               0         Thu    LAN       NL
# 171667               0         Thu    MIL       NL
# 171668               0         Thu    PIT       NL
# 171669               0         Thu    SLN       NL
# 171756               0         Thu    BOS       AL
# 171757               0         Thu    KCA       AL
# 171758               0         Thu    ANA       AL
# 171759               1         Thu    DET       AL
# 171760               2         Thu    DET       AL
# 171761               0         Thu    NYA       AL
# 171762               0         Thu    COL       NL
# 171763               0         Thu    ATL       NL
# 171764               0         Thu    PIT       NL
# 171765               0         Thu    PHI       NL
# 171766               0         Thu    SFN       NL
# 171851               0         Thu    TBA       AL
# 171852               0         Thu    MIN       AL
# 171853               0         Thu    BOS       AL
# 171854               0         Thu    OAK       AL
# 171855               0         Thu    BAL       AL
# 171856               0         Thu    PHI       NL
# 171857               0         Thu    CHN       NL
# 171858               0         Thu    LAN       NL
# 171859               0         Thu    COL       NL
# 171860               0         Thu    CIN       NL
# 171861               0         Thu    ARI       NL
#
# [21780 rows x 4 columns]
#
#         number_of_game day_of_week v_name v_league
# 4                    0         Tue    BS1       na
# 9                    0         Tue    TRO       na
# 10                   0         Tue    WS3       na
# 18                   0         Tue    RC1       na
# 26                   0         Tue    RC1       na
# 35                   0         Tue    CH1       na
# 43                   0         Tue    NY2       na
# 57                   0         Tue    BS1       na
# 58                   0         Tue    RC1       na
# 59                   0         Tue    CL1       na
# 80                   0         Tue    NY2       na
# 87                   0         Tue    CL1       na
# 88                   0         Tue    BS1       na
# 93                   0         Tue    BS1       na
# 98                   0         Tue    TRO       na
# 105                  0         Tue    CH1       na
# 106                  0         Tue    RC1       na
# 110                  0         Tue    CL1       na
# 130                  0         Tue    NY2       na
# 137                  0         Tue    BS1       na
# 146                  0         Tue    BS1       na
# 147                  0         Tue    WS3       na
# 148                  0         Tue    TRO       na
# 156                  0         Tue    CL1       na
# 167                  0         Tue    CL1       na
# 168                  0         Tue    PH1       na
# 169                  0         Tue    BR1       na
# 188                  0         Tue    TRO       na
# 197                  0         Tue    BR2       na
# 208                  0         Tue    CL1       na
# ...                ...         ...    ...      ...
# 171727               0         Tue    BOS       AL
# 171728               0         Tue    KCA       AL
# 171729               0         Tue    DET       AL
# 171730               0         Tue    HOU       AL
# 171731               0         Tue    TOR       AL
# 171732               0         Tue    NYA       AL
# 171733               0         Tue    ANA       AL
# 171734               0         Tue    CIN       NL
# 171735               0         Tue    SLN       NL
# 171736               0         Tue    SFN       NL
# 171737               0         Tue    WAS       NL
# 171738               0         Tue    PIT       NL
# 171739               0         Tue    ATL       NL
# 171740               0         Tue    CHA       AL
# 171741               0         Tue    ARI       NL
# 171821               0         Tue    OAK       AL
# 171822               0         Tue    TBA       AL
# 171823               0         Tue    CLE       AL
# 171824               0         Tue    SEA       AL
# 171825               0         Tue    MIN       AL
# 171826               0         Tue    BOS       AL
# 171827               0         Tue    MIL       NL
# 171828               0         Tue    BAL       AL
# 171829               0         Tue    PHI       NL
# 171830               0         Tue    NYN       NL
# 171831               0         Tue    CHN       NL
# 171832               0         Tue    LAN       NL
# 171833               0         Tue    COL       NL
# 171834               0         Tue    CIN       NL
# 171835               0         Tue    ARI       NL
#
# [24887 rows x 4 columns]
#
#         number_of_game day_of_week v_name v_league
# 11                   0         Wed    WS3       na
# 19                   0         Wed    WS3       na
# 20                   0         Wed    RC1       na
# 36                   0         Wed    CL1       na
# 37                   0         Wed    RC1       na
# 44                   0         Wed    FW1       na
# 45                   0         Wed    WS3       na
# 51                   0         Wed    PH1       na
# 52                   0         Wed    FW1       na
# 66                   0         Wed    BS1       na
# 75                   0         Wed    NY2       na
# 91                   0         Wed    WS3       na
# 99                   0         Wed    CH1       na
# 100                  0         Wed    TRO       na
# 107                  0         Wed    CL1       na
# 108                  0         Wed    RC1       na
# 111                  0         Wed    TRO       na
# 116                  0         Wed    WS3       na
# 117                  0         Wed    BS1       na
# 120                  0         Wed    NY2       na
# 123                  0         Wed    NY2       na
# 131                  0         Wed    NY2       na
# 138                  0         Wed    BL1       na
# 139                  0         Wed    BS1       na
# 149                  0         Wed    BS1       na
# 150                  0         Wed    TRO       na
# 157                  0         Wed    TRO       na
# 158                  0         Wed    CL1       na
# 170                  0         Wed    CL1       na
# 174                  0         Wed    MID       na
# ...                ...         ...    ...      ...
# 171659               0         Wed    NYN       NL
# 171742               0         Wed    BOS       AL
# 171743               0         Wed    KCA       AL
# 171744               0         Wed    HOU       AL
# 171745               0         Wed    TOR       AL
# 171746               0         Wed    NYA       AL
# 171747               0         Wed    ANA       AL
# 171748               0         Wed    CIN       NL
# 171749               0         Wed    SLN       NL
# 171750               0         Wed    SFN       NL
# 171751               0         Wed    WAS       NL
# 171752               0         Wed    PIT       NL
# 171753               0         Wed    ATL       NL
# 171754               0         Wed    CHA       AL
# 171755               0         Wed    ARI       NL
# 171836               0         Wed    OAK       AL
# 171837               0         Wed    TBA       AL
# 171838               0         Wed    CLE       AL
# 171839               0         Wed    SEA       AL
# 171840               0         Wed    MIN       AL
# 171841               0         Wed    BOS       AL
# 171842               0         Wed    MIL       NL
# 171843               0         Wed    BAL       AL
# 171844               0         Wed    PHI       NL
# 171845               0         Wed    NYN       NL
# 171846               0         Wed    CHN       NL
# 171847               0         Wed    LAN       NL
# 171848               0         Wed    COL       NL
# 171849               0         Wed    CIN       NL
# 171850               0         Wed    ARI       NL
#
# [25431 rows x 4 columns]

# %%
df8=df["h_name"].value_counts()

df8.head()
# Out:
# CHN    9024
# PHI    8648
# PIT    8470
# CIN    8312
# SLN    8138
# Name: h_name, dtype: int64

# %%
df[df.apply(lambda x: x['h_score'] > x['v_score'], axis=1)]
# Out:
#             date  number_of_game day_of_week v_name v_league  v_game_number  \
# 0       18710504               0         Thu    CL1       na              1
# 3       18710508               0         Mon    CL1       na              3
# 8       18710515               0         Mon    WS3       na              3
# 10      18710516               0         Tue    WS3       na              4
# 11      18710517               0         Wed    WS3       na              5
# 13      18710519               0         Fri    WS3       na              6
# 14      18710520               0         Sat    PH1       na              1
# 16      18710522               0         Mon    RC1       na              3
# 20      18710524               0         Wed    RC1       na              5
# 22      18710526               0         Fri    RC1       na              6
# 25      18710529               0         Mon    RC1       na              7
# 26      18710530               0         Tue    RC1       na              8
# 27      18710601               0         Thu    RC1       na              9
# 29      18710602               0         Fri    TRO       na              7
# 30      18710603               0         Sat    TRO       na              8
# 31      18710605               0         Mon    CH1       na              8
# 33      18710608               0         Thu    CH1       na              9
# 35      18710613               0         Tue    CH1       na             10
# 37      18710614               0         Wed    RC1       na             11
# 42      18710619               0         Mon    CL1       na             11
# 44      18710621               0         Wed    FW1       na              7
# 45      18710621               0         Wed    WS3       na             14
# 46      18710622               0         Thu    WS3       na             15
# 47      18710624               0         Sat    RC1       na             13
# 49      18710626               0         Mon    CL1       na             12
# 50      18710626               0         Mon    BS1       na             13
# 52      18710628               0         Wed    FW1       na              9
# 55      18710701               0         Sat    FW1       na             10
# 56      18710703               0         Mon    NY2       na             13
# 58      18710704               0         Tue    RC1       na             14
# ...          ...             ...         ...    ...      ...            ...
# 171847  20160928               0         Wed    LAN       NL            158
# 171853  20160929               0         Thu    BOS       AL            159
# 171854  20160929               0         Thu    OAK       AL            159
# 171856  20160929               0         Thu    PHI       NL            159
# 171859  20160929               0         Thu    COL       NL            159
# 171860  20160929               0         Thu    CIN       NL            159
# 171861  20160929               0         Thu    ARI       NL            159
# 171862  20160930               0         Fri    HOU       AL            160
# 171863  20160930               0         Fri    TOR       AL            160
# 171864  20160930               0         Fri    MIN       AL            160
# 171867  20160930               0         Fri    OAK       AL            160
# 171868  20160930               0         Fri    TBA       AL            160
# 171869  20160930               0         Fri    SDN       NL            160
# 171872  20160930               0         Fri    MIL       NL            160
# 171874  20160930               0         Fri    LAN       NL            160
# 171875  20160930               0         Fri    PIT       NL            160
# 171881  20161001               0         Sat    BAL       AL            161
# 171884  20161001               0         Sat    SDN       NL            161
# 171885  20161001               0         Sat    DET       AL            160
# 171886  20161001               0         Sat    CHN       NL            161
# 171889  20161001               0         Sat    LAN       NL            161
# 171890  20161001               0         Sat    PIT       NL            161
# 171891  20161001               0         Sat    MIA       NL            160
# 171892  20161002               0         Sun    HOU       AL            162
# 171899  20161002               0         Sun    SDN       NL            162
# 171900  20161002               0         Sun    DET       AL            161
# 171903  20161002               0         Sun    NYN       NL            162
# 171904  20161002               0         Sun    LAN       NL            162
# 171905  20161002               0         Sun    PIT       NL            162
# 171906  20161002               0         Sun    MIA       NL            161
#
#        h_name h_league  h_game_number  v_score       ...         \
# 0         FW1       na              1        0       ...
# 3         CH1       na              1       12       ...
# 8         FW1       na              3        6       ...
# 10        CH1       na              4        4       ...
# 11        RC1       na              2       12       ...
# 13        CH1       na              5        7       ...
# 14        BS1       na              4        8       ...
# 16        CH1       na              6        6       ...
# 20        CL1       na              7       10       ...
# 22        TRO       na              6       15       ...
# 25        BS1       na              7       11       ...
# 26        BS1       na              8       10       ...
# 27        NY2       na              3        3       ...
# 29        WS3       na             11        8       ...
# 30        PH1       na              2        5       ...
# 31        NY2       na              4        5       ...
# 33        PH1       na              4       11       ...
# 35        WS3       na             12        3       ...
# 37        NY2       na              5        4       ...
# 42        NY2       na              7        6       ...
# 44        BS1       na             12        0       ...
# 45        PH1       na              8        2       ...
# 46        NY2       na              9        4       ...
# 47        CH1       na             11        8       ...
# 49        WS3       na             16        3       ...
# 50        PH1       na              9        8       ...
# 52        NY2       na             11        0       ...
# 55        PH1       na             12        3       ...
# 56        TRO       na             12       16       ...
# 58        CH1       na             13       13       ...
# ...       ...      ...            ...      ...       ...
# 171847    SDN       NL            158        5       ...
# 171853    NYA       AL            159        1       ...
# 171854    SEA       AL            159        2       ...
# 171856    ATL       NL            158        2       ...
# 171859    SFN       NL            159        2       ...
# 171860    SLN       NL            159        3       ...
# 171861    WAS       NL            159        3       ...
# 171862    ANA       AL            160        1       ...
# 171863    BOS       AL            160        3       ...
# 171864    CHA       AL            160        3       ...
# 171867    SEA       AL            160        1       ...
# 171868    TEX       AL            160        1       ...
# 171869    ARI       NL            160        3       ...
# 171872    COL       NL            160        1       ...
# 171874    SFN       NL            160        3       ...
# 171875    SLN       NL            160        0       ...
# 171881    NYA       AL            161        3       ...
# 171884    ARI       NL            161        5       ...
# 171885    ATL       NL            160        3       ...
# 171886    CIN       NL            161        4       ...
# 171889    SFN       NL            161        0       ...
# 171890    SLN       NL            161        3       ...
# 171891    WAS       NL            161        1       ...
# 171892    ANA       AL            162        1       ...
# 171899    ARI       NL            162        2       ...
# 171900    ATL       NL            161        0       ...
# 171903    PHI       NL            162        2       ...
# 171904    SFN       NL            162        1       ...
# 171905    SLN       NL            162        4       ...
# 171906    WAS       NL            162        7       ...
#
#            h_player_7_name  h_player_7_def_pos h_player_8_id  h_player_8_name  \
# 0               Ed Mincher                 7.0      mcdej101  James McDermott
# 3                 Ed Duffy                 6.0      pinke101       Ed Pinkham
# 8               Ed Mincher                 7.0      donnp101    Pete Donnelly
# 10                Ed Duffy                 6.0      pinke101       Ed Pinkham
# 11               Cap Anson                 2.0      sagep101       Pony Sager
# 13                Ed Duffy                 6.0      pinke101       Ed Pinkham
# 14           Harry Schafer                 5.0      conef101        Fred Cone
# 16                Ed Duffy                 6.0      pinke101       Ed Pinkham
# 20             Ezra Sutton                 5.0      johnc105  William Johnson
# 22            Steve Bellan                 5.0      connn101       Ned Connor
# 25           Harry Schafer                 5.0      conef101        Fred Cone
# 26           Harry Schafer                 5.0      barrf102    Frank Barrows
# 27             Dave Eggler                 8.0      woltr101    Rynie Wolters
# 29            Asa Brainard                 1.0      hallg101      George Hall
# 30      Count Sensenderfer                 8.0      meyel102     Levi Meyerle
# 31             Dave Eggler                 8.0      woltr101    Rynie Wolters
# 33      Count Sensenderfer                 8.0      meyel102     Levi Meyerle
# 35            Asa Brainard                 1.0      hallg101      George Hall
# 37             Dave Eggler                 8.0      woltr101    Rynie Wolters
# 42             Dave Eggler                 8.0      woltr101    Rynie Wolters
# 44           Harry Schafer                 5.0      conef101        Fred Cone
# 45      Count Sensenderfer                 8.0      meyel102     Levi Meyerle
# 46             Dave Eggler                 8.0      woltr101    Rynie Wolters
# 47                Ed Duffy                 6.0      pinke101       Ed Pinkham
# 49            Bill Stearns                 1.0      hallg101      George Hall
# 50      Count Sensenderfer                 8.0      meyel102     Levi Meyerle
# 52             Dave Eggler                 8.0      woltr101    Rynie Wolters
# 55      Count Sensenderfer                 8.0      meyel102     Levi Meyerle
# 56                Lip Pike                 9.0      bells101     Steve Bellan
# 58              Ed Pinkham                 9.0      hodec101    Charlie Hodes
# ...                    ...                 ...           ...              ...
# 171847       Austin Hedges                 2.0      amara001   Alexi Amarista
# 171853        Brian McCann                 2.0      hicka001      Aaron Hicks
# 171854       Leonys Martin                 8.0      zunim001      Mike Zunino
# 171856       Jace Peterson                 4.0      ruizr002         Rio Ruiz
# 171859           Joe Panik                 4.0      gillc001  Conor Gillaspie
# 171860        Aledmys Diaz                 6.0      martj008    Jose Martinez
# 171861      Michael Taylor                 9.0      sevep001   Pedro Severino
# 171862       Rafael Ortega                 8.0      cowak001     Kaleb Cowart
# 171863      Jackie Bradley                 8.0      leons001       Sandy Leon
# 171864      Yolmer Sanchez                 4.0      narvo001     Omar Narvaez
# 171867       Leonys Martin                 8.0      zunim001      Mike Zunino
# 171868       Shin-Soo Choo                 9.0      morem001   Mitch Moreland
# 171869      Socrates Brito                 9.0      hanim001    Mitch Haniger
# 171872    Stephen Cardullo                 3.0      descd001  Daniel Descalso
# 171874     Kelby Tomlinson                 4.0      beckg001   Gordon Beckham
# 171875         Jedd Gyorko                 4.0      gricr001   Randal Grichuk
# 171881       Austin Romine                 2.0      austt001     Tyler Austin
# 171884           Jake Lamb                 5.0      herno002  Oscar Hernandez
# 171885       Jace Peterson                 4.0      swand001   Dansby Swanson
# 171886    Patrick Kivlehan                 9.0      cabrr001    Ramon Cabrera
# 171889      Gordon Beckham                 5.0      panij002        Joe Panik
# 171890         Jedd Gyorko                 4.0      gricr001   Randal Grichuk
# 171891      Pedro Severino                 2.0      espid001   Danny Espinosa
# 171892       Rafael Ortega                 8.0      perec003     Carlos Perez
# 171899       Mitch Haniger                 8.0      goset001  Tuffy Gosewisch
# 171900       Jace Peterson                 4.0      swand001   Dansby Swanson
# 171903       Andres Blanco                 6.0      altha001    Aaron Altherr
# 171904           Joe Panik                 4.0      gillc001  Conor Gillaspie
# 171905         Jedd Gyorko                 4.0      gricr001   Randal Grichuk
# 171906      Danny Espinosa                 6.0      lobaj001     Jose Lobaton
#
#        h_player_8_def_pos h_player_9_id    h_player_9_name  \
# 0                     8.0      kellb105         Bill Kelly
# 3                     5.0      zettg101    George Zettlein
# 8                     9.0      kellb105         Bill Kelly
# 10                    5.0      zettg101    George Zettlein
# 11                    6.0      birdg101        George Bird
# 13                    5.0      zettg101    George Zettlein
# 14                    7.0      spala101        Al Spalding
# 16                    5.0      zettg101    George Zettlein
# 20                    9.0      bassj101          John Bass
# 22                    3.0      cravb101        Bill Craver
# 25                    7.0      spala101        Al Spalding
# 26                    7.0      spala101        Al Spalding
# 27                    1.0      pattd103      Tom Patterson
# 29                    8.0      berth101    Henry Berthrong
# 30                    5.0      heubg101      George Heubel
# 31                    1.0      pattd103      Tom Patterson
# 33                    5.0      heubg101      George Heubel
# 35                    8.0      berth101    Henry Berthrong
# 37                    1.0      pattd103      Tom Patterson
# 42                    1.0      pattd103      Tom Patterson
# 44                    7.0      spala101        Al Spalding
# 45                    5.0      heubg101      George Heubel
# 46                    1.0      pattd103      Tom Patterson
# 47                    5.0      zettg101    George Zettlein
# 49                    8.0      berth101    Henry Berthrong
# 50                    5.0      heubg101      George Heubel
# 52                    1.0      pattd103      Tom Patterson
# 55                    5.0      bechg101     George Bechtel
# 56                    5.0      cravb101        Bill Craver
# 58                    6.0      zettg101    George Zettlein
# ...                   ...           ...                ...
# 171847                6.0      perdl002       Luis Perdomo
# 171853                9.0      austt001       Tyler Austin
# 171854                2.0      martk001        Ketel Marte
# 171856                5.0      collj001    Josh Collmenter
# 171859                5.0      cuetj001       Johnny Cueto
# 171860                7.0      reyea004         Alex Reyes
# 171861                2.0      rossj002           Joe Ross
# 171862                4.0      choij001        Ji-Man Choi
# 171863                2.0      benia002  Andrew Benintendi
# 171864                2.0      garcl004       Leury Garcia
# 171867                2.0      martk001        Ketel Marte
# 171868                3.0      andre001       Elvis Andrus
# 171869                8.0      shipb001     Braden Shipley
# 171872                6.0      bettc001        Chad Bettis
# 171874                5.0      bumgm001  Madison Bumgarner
# 171875                8.0      martc006    Carlos Martinez
# 171881                9.0      torrr001    Ronald Torreyes
# 171884                2.0      brada001     Archie Bradley
# 171885                6.0      blaia001        Aaron Blair
# 171886                2.0      adlet001        Tim Adleman
# 171889                4.0      blact002           Ty Blach
# 171890                8.0      wachm001      Michael Wacha
# 171891                6.0      roart001       Tanner Roark
# 171892                2.0      pennc001   Cliff Pennington
# 171899                2.0      kochm001          Matt Koch
# 171900                6.0      tehej001      Julio Teheran
# 171903                9.0      eickj001     Jerad Eickhoff
# 171904                5.0      moorm003         Matt Moore
# 171905                8.0      waina001    Adam Wainwright
# 171906                2.0      schem001       Max Scherzer
#
#         h_player_9_def_pos  additional_info acquisition_info
# 0                      9.0              NaN                Y
# 3                      1.0              NaN                Y
# 8                      8.0              NaN                Y
# 10                     1.0              NaN                Y
# 11                     8.0              NaN                Y
# 13                     1.0             HTBF                Y
# 14                     1.0             HTBF                Y
# 16                     1.0              NaN                Y
# 20                     6.0              NaN                Y
# 22                     2.0              NaN                Y
# 25                     1.0              NaN                Y
# 26                     1.0             HTBF                Y
# 27                     9.0             HTBF                Y
# 29                     7.0             HTBF                Y
# 30                     9.0             HTBF                Y
# 31                     9.0             HTBF                Y
# 33                     9.0             HTBF                Y
# 35                     7.0              NaN                Y
# 37                     9.0              NaN                Y
# 42                     9.0             HTBF                Y
# 44                     1.0             HTBF                Y
# 45                     9.0              NaN                Y
# 46                     9.0             HTBF                Y
# 47                     1.0              NaN                Y
# 49                     7.0             HTBF                Y
# 50                     9.0              NaN                Y
# 52                     9.0             HTBF                Y
# 55                     9.0             HTBF                Y
# 56                     4.0              NaN                Y
# 58                     1.0              NaN                Y
# ...                    ...              ...              ...
# 171847                 1.0              NaN                Y
# 171853                 3.0              NaN                Y
# 171854                 6.0              NaN                Y
# 171856                 1.0              NaN                Y
# 171859                 1.0              NaN                Y
# 171860                 1.0              NaN                Y
# 171861                 1.0              NaN                Y
# 171862                 7.0              NaN                Y
# 171863                 7.0              NaN                Y
# 171864                 8.0              NaN                Y
# 171867                 6.0              NaN                Y
# 171868                 6.0              NaN                Y
# 171869                 1.0              NaN                Y
# 171872                 1.0              NaN                Y
# 171874                 1.0              NaN                Y
# 171875                 1.0              NaN                Y
# 171881                 6.0              NaN                Y
# 171884                 1.0              NaN                Y
# 171885                 1.0              NaN                Y
# 171886                 1.0              NaN                Y
# 171889                 1.0              NaN                Y
# 171890                 1.0              NaN                Y
# 171891                 1.0              NaN                Y
# 171892                 4.0              NaN                Y
# 171899                 1.0              NaN                Y
# 171900                 1.0              NaN                Y
# 171903                 1.0              NaN                Y
# 171904                 1.0              NaN                Y
# 171905                 1.0              NaN                Y
# 171906                 1.0              NaN                Y
#
# [93587 rows x 161 columns]

# %%
df10 = df1[['length_minutes','h_score']]
df10 = df10.head(1000)
ax1 = df10.plot(kind='scatter', x='length_minutes', y='h_score', color='b')   
print(ax1)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
